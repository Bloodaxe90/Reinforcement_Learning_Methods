# %%
from src.rl_methods.model_free.reinforce import REINFORCE

re = REINFORCE(
    size=4,
    player_pos=(0, 0),
    num_food=3,
    nuke_prob= 0.5,
    intended_action_prob=1.0
)
env_copy = re.environment.copy()
# Out:
# Environment Generated with:
#   - Player at position (0, 0)
#   - 3 pieces of Food
#   - 6 nukes
#
# Environment:
# [[' () ' '----' 'FOOD' '----']
#  ['NUKE' '----' '----' 'NUKE']
#  ['NUKE' 'FOOD' '----' 'FOOD']
#  ['NUKE' 'NUKE' 'NUKE' '----']]
# 5
# 20

# %%
re.environment = env_copy.copy()
re.train(20000)
# Out:
# TRAINING BEGUN

# %%
re.environment = env_copy.copy()
re.play()
# Out:
# Initial Environment:
#  [[' () ' '----' 'FOOD' '----']
#  ['NUKE' '----' '----' 'NUKE']
#  ['NUKE' 'FOOD' '----' 'FOOD']
#  ['NUKE' 'NUKE' 'NUKE' '----']]
#
# 1.
# [['----' ' () ' 'FOOD' '----']
#  ['NUKE' '----' '----' 'NUKE']
#  ['NUKE' 'FOOD' '----' 'FOOD']
#  ['NUKE' 'NUKE' 'NUKE' '----']]
# Intended Move
#
# 2.
# [['----' '----' '(FOOD)' '----']
#  ['NUKE' '----' '----' 'NUKE']
#  ['NUKE' 'FOOD' '----' 'FOOD']
#  ['NUKE' 'NUKE' 'NUKE' '----']]
# Intended Move
#
# 3.
# [['----' '----' '----' '----']
#  ['NUKE' '----' ' () ' 'NUKE']
#  ['NUKE' 'FOOD' '----' 'FOOD']
#  ['NUKE' 'NUKE' 'NUKE' '----']]
# Intended Move
#
# 4.
# [['----' '----' '----' '----']
#  ['NUKE' ' () ' '----' 'NUKE']
#  ['NUKE' 'FOOD' '----' 'FOOD']
#  ['NUKE' 'NUKE' 'NUKE' '----']]
# Intended Move
#
# 5.
# [['----' '----' '----' '----']
#  ['NUKE' '----' '----' 'NUKE']
#  ['NUKE' '(FOOD)' '----' 'FOOD']
#  ['NUKE' 'NUKE' 'NUKE' '----']]
# Intended Move
#
# 6.
# [['----' '----' '----' '----']
# ...
